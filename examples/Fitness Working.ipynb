# %%
from fears.population import Population
from fears.utils import fitness,plotter

p = Population(fitness_data='from_file')

# %%
# plot the fitness seascape
fig,ax = p.plot_fitness_curves()
# Out:
# C:\Users\annae\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\fears-0.1.0-py3.10.egg\fears\utils\fitness.py:555: RuntimeWarning: overflow encountered in exp
#   g = g_drugless/(1+np.exp((IC50-np.log10(x))/hill_coeff))

# %%
# plot some fitness landscapes at different drug concentrations
plotter.plot_landscape(p,10**-3, arrows=True)

plotter.plot_landscape(p,10**-2, arrows=True)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# c:\Users\annae\Downloads\CODE\CC Lab\fears\examples\Fitness Working.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/annae/Downloads/CODE/CC%20Lab/fears/examples/Fitness%20Working.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> # plot some fitness landscapes at different drug concentrations
# ----> <a href='vscode-notebook-cell:/c%3A/Users/annae/Downloads/CODE/CC%20Lab/fears/examples/Fitness%20Working.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> plotter.plot_landscape(p,10**-3, arrows=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/annae/Downloads/CODE/CC%20Lab/fears/examples/Fitness%20Working.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> plotter.plot_landscape(p,10**-2, arrows=True)
#
# ...

# %%
# enumerate neighbors

print(p.gen_neighbors(0)) # genotype 0 (0000) neighbors
print(p.gen_neighbors(1))
print(p.gen_neighbors(2))
print(p.gen_neighbors(3))
print(p.gen_neighbors(4))
print(p.gen_neighbors(6))
print(p.gen_neighbors(15)) # genotype 15 (1111) neighbors
# Out:
# [1, 2, 4, 8]
# [0, 3, 5, 9]
# [3, 0, 6, 10]
# [2, 1, 7, 11]
# [5, 6, 0, 12]
# [7, 4, 2, 14]
# [14, 13, 11, 7]

# %%
plotter
# Out:
# <module 'fears.utils.plotter' from 'C:\\Users\\annae\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python310\\site-packages\\fears-0.1.0-py3.10.egg\\fears\\utils\\plotter.py'>
